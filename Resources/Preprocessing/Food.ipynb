# %%
import pandas as pd
import numpy as np

# %%
dfs = pd.read_excel(r'C:\Users\Jagatheesh\OneDrive\Desktop\Heriot_Watt_University_Msc_Data_Science\Data_Viz_CW2\Cost_of_living_crisis_UK_Storyboard\Resources\DataSet\Food.xlsx', sheet_name=['Indices', 'Growth Rates', 'Contributions','Sample sizes','Weights'])

# Access individual dataframes by sheet name
df_sheet1 = dfs['Indices']
df_sheet2 = dfs['Growth Rates']
df_sheet3 = dfs['Contributions']
df_sheet4 = dfs['Sample sizes']
df_sheet5 = dfs['Weights']

# %%
df_sheet2
# Out:
#     Online weekly price changes for food & drink items: weekly growth rates  \
# 0
# 1                                             Category
# 2                                           Aggregated
# 3                                                 Beer
# 4
# ..                                                 ...
# 156
# 157
# 158                   (Office for National Statistics)
# 159                                  (: not available)
# 160  (Out of stock products have been removed where...
#
#          Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0               NaN         NaN         NaN         NaN         NaN
# 1              Item  07-06-2020  14-06-2020  21-06-2020  28-06-2020
# 2        Aggregated           :           0        -0.1        -0.1
# 3        Aggregated           :        -0.3        -0.1           0
# 4        Lager beer           :        -0.4        -0.2           0
# ..              ...         ...         ...         ...         ...
# ...

# %%
df_sheet1
# Out:
#     Online weekly price changes for food & drink items: weekly indices  \
# 0
# 1                                             Category
# 2                                           Aggregated
# 3                                                 Beer
# 4
# ..                                                 ...
# 156
# 157
# 158                   (Office for National Statistics)
# 159                                  (: not available)
# 160  (Out of stock products have been removed where...
#
#          Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0               NaN         NaN         NaN         NaN         NaN
# 1              Item  07-06-2020  14-06-2020  21-06-2020  28-06-2020
# 2        Aggregated         100         100        99.9        99.8
# 3        Aggregated         100        99.7        99.6        99.6
# 4        Lager beer         100        99.6        99.5        99.5
# ..              ...         ...         ...         ...         ...
# ...
